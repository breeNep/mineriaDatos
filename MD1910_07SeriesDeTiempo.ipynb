# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
url = 'https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/data_nybirths.dat'
df_births = pd.read_csv(url, header=None, names=['Births'])
df_births
# Out:
#      Births
# 0    26.663
# 1    23.598
# 2    26.931
# 3    24.740
# 4    25.806
# ..      ...
# 163  30.000
# 164  29.261
# 165  29.012
# 166  26.992
# 167  27.897
#
# [168 rows x 1 columns]

# %%
df_births.index = pd.date_range(start='1946-01', periods=len(df_births), freq='M')
df_births
# Out:
#             Births
# 1946-01-31  26.663
# 1946-02-28  23.598
# 1946-03-31  26.931
# 1946-04-30  24.740
# 1946-05-31  25.806
# ...            ...
# 1959-08-31  30.000
# 1959-09-30  29.261
# 1959-10-31  29.012
# 1959-11-30  26.992
# 1959-12-31  27.897
#
# [168 rows x 1 columns]

# %%
df_births.plot()
plt.title('New York Monthly Live Birth 1946-1959')
plt.xlabel('Year')
plt.ylabel('Number of birth')
plt.show()

# %%
#Sacamos mes
df_births['Month'] = df_births.index.month
df_births
# Out:
#             Births  Month
# 1946-01-31  26.663      1
# 1946-02-28  23.598      2
# 1946-03-31  26.931      3
# 1946-04-30  24.740      4
# 1946-05-31  25.806      5
# ...            ...    ...
# 1959-08-31  30.000      8
# 1959-09-30  29.261      9
# 1959-10-31  29.012     10
# 1959-11-30  26.992     11
# 1959-12-31  27.897     12
#
# [168 rows x 2 columns]

# %%
plt.figure(figsize=(12,8))
df_births.boxplot(column='Births', by='Month')
plt.ylabel('Number of births')
#Nacimientoss registrados independientemente del mes
# Out:
# Text(0, 0.5, 'Number of births')

# %%
#Tendencia(estacionalidad)no tenga un patron estable
plt.figure(figsize=(12,8))
decomposition = seasonal_decompose(df_births['Births'], model='additive', period=12)
decomposition.plot()
plt.show()

# %%
#Cada elemento separado
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(decomposition.trend)
